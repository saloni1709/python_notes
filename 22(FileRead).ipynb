# %%
f = open("22demo.txt", "r")
data = f.read()
print(data)
print(type(data))
f.close()
# Out:
# Hello World!
# I am Saloni Goyal.
# <class 'str'>

# %%
# f = open("22demo.txt", "r")
# data = f.read(8)
# print(data)
# f.close()

# %%
f = open("22demo.txt", "r")
line1 = f.readline()
print(line1)
f.close()
# Out:
# Hello World!
