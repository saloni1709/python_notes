# %% [markdown]
# ## IF-ELSE

# %%
age = 20

if(age>=18):
    print("You can vote")
else:
    print("You can't vote")
# Out:
# You can vote

# %%
light = "green"

if(light == "red"):
    print("stop")
elif(light == "green"):
    print("go")
elif(light == "yellow"):
    print("look")
else:
    print("Invalid")
# Out:
# go
